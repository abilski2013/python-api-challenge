# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# Key Observations: the temperature does trend warmer closer to the equator. The time we are running this analysis (January 2020) is "winter" in the northern hemisphere and "summer" in the southern hemisphere, so the trend therefore, of warmer temperatures closer to the equator, is more pronounced in the northern hemisphere. One other trend I noticed was with wind speed. Although there was not a strong correlation in either the northern or southern hemisphere with wind speed and distance from the equator, the very extreme wind speeds (outliers) were very far away from the equator. Other observations noted throughout the notebook below.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
city_name = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

for city in cities:
    
    response = requests.get(query_url + city).json()
    
    try:
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Able to process {city}")

    except:
        print(f"not able to process {city}... skipping")
        pass
# Out:
# Able to process blairmore
# Able to process bluff
# Able to process chapada dos guimaraes
# Able to process vao
# Able to process tsumeb
# Able to process manta
# Able to process mataura
# Able to process kapaa
# Able to process albany
# Able to process burnie
# Able to process iracoubo
# Able to process puerto ayora
# Able to process beringovskiy
# Able to process provideniya
# Able to process airai
# Able to process ostashkov
# Able to process castro
# Able to process shiraz
# Able to process new norfolk
# not able to process belushya guba... skipping
# Able to process ushuaia
# not able to process burica... skipping
# Able to process port alfred
# Able to process lorengau
# Able to process isangel
# Able to process busselton
# Able to process berdigestyakh
# Able to process benguela
# Able to process thompson
# Able to process veranopolis
# Able to process nanortalik
# Able to process jizan
# Able to process haines junction
# Able to process northam
# Able to process hobart
# not able to process sentyabrskiy... skipping
# Able to process high prairie
# Able to process muros
# Able to process pangody
# Able to process pevek
# Able to process batemans bay
# Able to process huarmey
# Able to process vardo
# Able to process ribeira grande
# Able to process am timan
# Able to process upington
# Able to process vaini
# Able to process shubarshi
# Able to process balabac
# Able to process korla
# Able to process kozhva
# Able to process bilibino
# Able to process jamestown
# Able to process bredasdorp
# Able to process lavra
# Able to process qasigiannguit
# Able to process mayo
# Able to process birin
# Able to process punta arenas
# Able to process east london
# Able to process bubaque
# Able to process geraldton
# Able to process antofagasta
# Able to process qaanaaq
# Able to process necochea
# Able to process norman wells
# Able to process hithadhoo
# Able to process nanhai
# Able to process alofi
# not able to process marcona... skipping
# Able to process albanel
# Able to process yumen
# Able to process lang son
# Able to process morondava
# Able to process kaitangata
# Able to process tucuman
# Able to process finschhafen
# Able to process nioro
# not able to process taolanaro... skipping
# Able to process leningradskiy
# Able to process hilo
# Able to process rikitea
# Able to process inhambane
# not able to process illoqqortoormiut... skipping
# Able to process praia
# Able to process oyama
# Able to process pangai
# Able to process bethel
# Able to process ambon
# Able to process ustka
# Able to process broome
# Able to process yellowknife
# Able to process lagoa
# Able to process asau
# Able to process hermanus
# Able to process arraial do cabo
# Able to process san luis
# Able to process revda
# Able to process fare
# Able to process tulagi
# Able to process yarada
# Able to process upernavik
# Able to process port hardy
# Able to process hasaki
# Able to process guerrero negro
# Able to process tra vinh
# Able to process lufilufi
# Able to process avarua
# Able to process miramar
# Able to process cockburn town
# Able to process butaritari
# Able to process port elizabeth
# Able to process sakaiminato
# not able to process tumannyy... skipping
# Able to process komsomolskiy
# not able to process azar shahr... skipping
# Able to process husavik
# Able to process ndioum
# Able to process saint george
# Able to process tuktoyaktuk
# Able to process tasiilaq
# Able to process bathsheba
# Able to process tiksi
# Able to process duluth
# Able to process luderitz
# Able to process vero beach
# Able to process hirado
# not able to process toliary... skipping
# Able to process victoria
# Able to process kloulklubed
# Able to process bambous virieux
# Able to process kavaratti
# Able to process dulmen
# Able to process xuddur
# Able to process chitral
# Able to process urucara
# Able to process sur
# not able to process barentsburg... skipping
# not able to process mys shmidta... skipping
# Able to process mildura
# Able to process lima
# not able to process bacuit... skipping
# Able to process nikolskoye
# Able to process kruisfontein
# Able to process douentza
# Able to process zilupe
# Able to process saint-philippe
# Able to process paka
# Able to process kununurra
# Able to process cairns
# Able to process sao filipe
# Able to process arman
# Able to process cap malheureux
# Able to process barrow
# Able to process souillac
# Able to process pangnirtung
# Able to process poltava
# Able to process zelenoborsk
# Able to process kahului
# Able to process longyearbyen
# Able to process hobyo
# Able to process karwar
# Able to process tucurui
# Able to process yerbogachen
# Able to process ancud
# Able to process totness
# Able to process lubao
# Able to process flin flon
# Able to process sitka
# Able to process ondangwa
# Able to process nhulunbuy
# Able to process olafsvik
# Able to process codrington
# Able to process mar del plata
# Able to process ixtapa
# not able to process palabuhanratu... skipping
# not able to process port-de-paix... skipping
# Able to process kralendijk
# Able to process sorong
# Able to process krasavino
# Able to process sinnamary
# Able to process marawi
# Able to process windhoek
# Able to process cape town
# Able to process lata
# Able to process vila
# Able to process ribas do rio pardo
# Able to process chimoio
# Able to process kodiak
# Able to process gairo
# Able to process maceio
# not able to process nizhneyansk... skipping
# Able to process atuona
# Able to process flinders
# Able to process gogrial
# Able to process pyay
# not able to process umzimvubu... skipping
# Able to process thunder bay
# Able to process avera
# Able to process chokurdakh
# Able to process hualmay
# Able to process narsaq
# Able to process dondo
# Able to process ust-kut
# Able to process guatire
# Able to process yenagoa
# Able to process puerto leguizamo
# Able to process vila franca do campo
# Able to process petropavlovsk-kamchatskiy
# Able to process shimoda
# Able to process saint-joseph
# not able to process attawapiskat... skipping
# Able to process tuatapere
# not able to process tabiauea... skipping
# Able to process coari
# Able to process touros
# Able to process saint-georges
# Able to process nome
# Able to process valparaiso
# Able to process luoyang
# Able to process medicine hat
# not able to process louisbourg... skipping
# Able to process waldkirchen
# Able to process jalu
# Able to process nigde
# Able to process abha
# Able to process cayenne
# Able to process moindou
# Able to process bodden town
# Able to process belmonte
# Able to process severo-kurilsk
# Able to process puerto princesa
# Able to process ginda
# Able to process benjamin hill
# Able to process mount gambier
# Able to process tabou
# Able to process tautira
# Able to process grand baie
# Able to process alice
# Able to process rio gallegos
# Able to process portland
# Able to process pisco
# Able to process neuquen
# Able to process ilulissat
# Able to process lavrentiya
# Able to process ponta do sol
# Able to process viedma
# Able to process mahibadhoo
# Able to process rock sound
# Able to process yarmouth
# Able to process jining
# Able to process havelock
# Able to process jiwani
# Able to process saskylakh
# Able to process caledon
# Able to process jaciara
# Able to process timbiqui
# Able to process antalaha
# Able to process westport
# Able to process umm lajj
# Able to process lebu
# Able to process galesong
# Able to process yulara
# Able to process severnyy
# Able to process bafoulabe
# Able to process saint-francois
# Able to process san patricio
# Able to process kungurtug
# Able to process buzdyak
# Able to process carnarvon
# Able to process anadyr
# Able to process khatanga
# Able to process ossora
# Able to process baker city
# Able to process boulder city
# Able to process orshanka
# Able to process humaita
# not able to process amderma... skipping
# Able to process kurilsk
# Able to process kijang
# Able to process harnai
# Able to process leopold
# Able to process ban nahin
# Able to process palana
# Able to process fort nelson
# Able to process tiznit
# Able to process kalemie
# Able to process ljungby
# Able to process chuy
# Able to process villa carlos paz
# Able to process mazabuka
# Able to process kampot
# Able to process tshela
# Able to process abu samrah
# Able to process nabire
# Able to process mahebourg
# Able to process yeppoon
# Able to process iberia
# Able to process mizdah
# Able to process mnogovershinnyy
# Able to process burdur
# Able to process qaqortoq
# Able to process barmer
# not able to process tsihombe... skipping
# Able to process pontes e lacerda
# Able to process tessaoua
# Able to process pacific grove
# Able to process faanui
# Able to process tete
# Able to process teya
# Able to process georgetown
# Able to process peterhead
# Able to process riachao das neves
# Able to process lamu
# Able to process harper
# Able to process mendes
# Able to process kinshasa
# Able to process buin
# Able to process vestmannaeyjar
# Able to process warmbad
# Able to process paducah
# Able to process adrar
# not able to process halalo... skipping
# Able to process kiruna
# Able to process inongo
# Able to process henties bay
# Able to process torbay
# Able to process kenai
# Able to process mount isa
# Able to process aykhal
# Able to process hambantota
# Able to process oranjestad
# Able to process leh
# Able to process maumere
# not able to process grand river south east... skipping
# Able to process victor harbor
# Able to process port lincoln
# Able to process buala
# Able to process narrabri
# Able to process ulcinj
# Able to process eldorado
# Able to process niquelandia
# Able to process iqaluit
# Able to process lac du bonnet
# Able to process zvishavane
# Able to process shenjiamen
# Able to process malinovskiy
# Able to process bardiyah
# Able to process uglovskoye
# Able to process juneau
# Able to process chifeng
# Able to process xai-xai
# Able to process comodoro rivadavia
# Able to process imbituba
# Able to process shaowu
# Able to process klaksvik
# Able to process trincomalee
# Able to process anloga
# Able to process nexo
# Able to process dikson
# not able to process vaitupu... skipping
# Able to process dukat
# Able to process port macquarie
# Able to process seoul
# Able to process mayumba
# Able to process verkh-usugli
# not able to process bolshiye kaybitsy... skipping
# Able to process teahupoo
# Able to process kursenai
# Able to process hamilton
# Able to process magdagachi
# Able to process college
# Able to process foundiougne
# not able to process gulshat... skipping
# Able to process cherskiy
# Able to process kamenka
# Able to process milicz
# Able to process batagay-alyta
# Able to process salalah
# Able to process coihaique
# Able to process clyde river
# Able to process porto de moz
# Able to process casablanca
# Able to process mackay
# not able to process saleaula... skipping
# Able to process deputatskiy
# Able to process san cristobal
# Able to process padang
# Able to process villa maria
# Able to process san quintin
# Able to process whitianga
# Able to process monte patria
# Able to process dzhubga
# Able to process walvis bay
# Able to process brownsville
# Able to process talnakh
# Able to process kangaatsiaq
# Able to process kuching
# Able to process awjilah
# not able to process mankovo-kalitvenskoye... skipping
# Able to process lenger
# Able to process bira
# Able to process iraan
# Able to process kavieng
# Able to process lumphat
# Able to process bengkulu
# Able to process msanga
# Able to process chimbote
# Able to process kashan
# Able to process bali chak
# Able to process concarneau
# not able to process kamenskoye... skipping
# Able to process bonavista
# Able to process xuanhua
# Able to process qingdao
# Able to process mugumu
# Able to process linhares
# Able to process margate
# Able to process elizabeth city
# Able to process impfondo
# Able to process taloqan
# Able to process lasa
# Able to process tricase
# Able to process aripuana
# Able to process poum
# Able to process port hawkesbury
# Able to process port moresby
# Able to process zhanaozen
# not able to process temaraia... skipping
# Able to process venustiano carranza
# Able to process zaoyang
# Able to process kismayo
# Able to process hovd
# Able to process santo amaro da imperatriz
# Able to process namatanai
# Able to process dunedin
# Able to process sekoma
# Able to process cidreira
# Able to process san rafael
# Able to process tayshet
# Able to process ajdabiya
# Able to process surgut
# Able to process hohhot
# Able to process esperance
# Able to process svetlaya
# Able to process pont-audemer
# Able to process saldanha
# Able to process cabedelo
# Able to process san policarpo
# Able to process laguna
# Able to process raudeberg
# Able to process road town
# not able to process artyk... skipping
# Able to process carballo
# Able to process locri
# Able to process sovetskiy
# Able to process colesberg
# Able to process lompoc
# Able to process ilula
# Able to process hofn
# Able to process sambava
# Able to process maldonado
# Able to process waipawa
# Able to process namie
# Able to process ximei
# Able to process pringsewu
# Able to process saint-louis
# Able to process constitucion
# Able to process noumea
# Able to process zhigansk
# Able to process sabinov
# Able to process diamantino
# Able to process oranjemund
# Able to process ambilobe
# Able to process lengshuitan
# Able to process aksarka
# Able to process korcula
# Able to process milkovo
# Able to process nizwa
# Able to process meadow lake
# Able to process bull savanna
# Able to process axim
# Able to process katsuura
# Able to process almeirim
# Able to process lazurne
# not able to process khonuu... skipping
# Able to process bulgan
# not able to process samusu... skipping
# Able to process lesnoy
# Able to process diffa
# Able to process sao joao da barra
# Able to process hami
# Able to process marsh harbour
# Able to process nova lima
# Able to process yinchuan
# Able to process verkhnevilyuysk
# Able to process broken arrow
# Able to process anori
# Able to process larap
# Able to process vila velha
# Able to process mormugao
# Able to process naze
# Able to process great falls
# Able to process erenhot
# Able to process bahia blanca
# Able to process senneterre
# Able to process mehamn
# Able to process chipinge
# Able to process mabua
# Able to process penzance
# Able to process nosy varika
# not able to process burkhala... skipping
# Able to process maracacume
# Able to process half moon bay
# Able to process yar-sale
# not able to process jiroft... skipping
# Able to process rocha
# Able to process sandusky
# Able to process owando
# Able to process balkanabat
# Able to process coquimbo
# Able to process tazmalt
# Able to process dennery
# Able to process rewari
# Able to process izhma
# Able to process kothi
# Able to process toamasina
# Able to process chinhoyi
# Able to process darnah
# Able to process bosaso
# not able to process balimo... skipping
# Able to process benito juarez
# Able to process namibe
# Able to process tura
# Able to process nokaneng
# Able to process lar
# Able to process bambanglipuro
# Able to process fortuna
# Able to process atambua
# Able to process maniitsoq
# Able to process sabzevar
# Able to process bartica
# Able to process makinsk
# Able to process novopodrezkovo
# Able to process verkhnetulomskiy
# Able to process chilca
# Able to process gat
# Able to process qeshm
# Able to process iquitos
# Able to process nouadhibou
# Able to process tarabha
# Able to process prince rupert
# Able to process shache
# Able to process dauphin
# Able to process malanje
# Able to process malim
# Able to process cochrane
# Able to process dudinka
# Able to process paamiut
# Able to process bintulu
# Able to process candido mendes
# Able to process molokovo
# Able to process duvan
# Able to process zwedru
# Able to process sabinas hidalgo
# Able to process faya
# Able to process herat
# Able to process mbandaka
# Able to process shingu
# Able to process bandarbeyla
# Able to process mersing
# Able to process pathein
# Able to process nago
# Able to process araouane
# Able to process mount pleasant
# Able to process nishihara
# Able to process hua hin
# Able to process egvekinot
# Able to process tabuk
# Able to process yaan
# Able to process belyy yar
# Able to process umea
# Able to process nantucket
# Able to process anderson
# Able to process grand gaube
# Able to process vega de alatorre
# Able to process gushikawa
# Able to process vostok
# not able to process grand centre... skipping
# Able to process amapa
# Able to process uyemskiy
# Able to process kondinskoye
# Able to process skibbereen

# %%
dataframe_results = pd.DataFrame({"City Name":city_name,
                                 "Cloudiness":cloudiness,
                                 "Country": country,
                                 "Date": date,
                                 "Humidity": humidity,
                                 "latitude": latitude,
                                 "longitude": longitude,
                                 "Max Temp (fahrenheit)": max_temp,
                                 "Wind Speed": wind_speed})

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
dataframe_results.to_csv(output_data_file)

# %%
dataframe_results.head()
# Out:
#                City Name  Cloudiness Country        Date  Humidity  latitude  \
# 0              Blairmore           1      CA  1579564413        52     49.60
# 1                  Bluff         100      NZ  1579564207        68    -46.60
# 2  Chapada dos Guimaraes          20      BR  1579564414        74    -15.46
# 3                    Vao          87      NC  1579564310        59    -22.67
# 4                 Tsumeb          38      NA  1579564414        29    -19.23
#
#    longitude  Max Temp (fahrenheit)  Wind Speed
# 0    -114.44                  42.80        5.37
# 1     168.33                  65.75        5.77
# 2     -55.75                  84.20        3.36
# 3     167.48                  76.71        5.97
# 4      17.72                  74.91       10.40

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Max Temp (fahrenheit)"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Max Temp")
plt.ylabel("Max Temp (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Max_Temp")
plt.show()

# %% [markdown]
# Above appears to show temperatures are higher around the equator (0 latitude) and temperatures trend lower as you go further away from the equator, both north and south.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Humidity"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Humidity")
plt.show()

# %% [markdown]
# Doesn't appear to be much pattern to humidity levels. You might say there are more lower humidity levels at the latitudes closer to the equator, but hard to tell from this scatter, because there are also a lot of very high humidity cities near and far from equator.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Cloudiness"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Cloudiness")
plt.show()

# %% [markdown]
# This isn't telling a whole lot either. It looks like there are particular numbers that are more frequently chosen to represent "cloudiness" in any given city. Would not be able to infer from this scatter that it is more or less cloudy near the equator.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Wind Speed"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Wind Speed")
plt.show()

# %% [markdown]
# Wind speeds this particular day were pretty consistent no matter what city. 0-20 would pretty much describe the wind speed both near or far from the equator - a couple outliers up well north of the equator with very high winds.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
fig_label=[]
def lin_reg(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values, "r-")
    plt.xlabel(x.name)
    plt.ylabel(y.name)
    plt.title(f'{x.name} vs {y.name}')
    plt.annotate(line_eq,(min(x),min(y)),fontsize=15, color="red")
    plt.savefig(f"output_data/{x.name}vs{y.name}:{fig_label}")
    plt.show()
    print(f'The r value is: {rvalue}')

# %%
# Create Northern and Southern Hemisphere DataFrames
north = dataframe_results.loc[dataframe_results["latitude"]>=0]
south = dataframe_results.loc[dataframe_results["latitude"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
fig_label = "north"
x = north["latitude"]
y = north["Max Temp (fahrenheit)"]
lin_reg(x,y)
# Out:
# The r value is: -0.8627628878348348

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
fig_label = "south"
x = south["latitude"]
y = south["Max Temp (fahrenheit)"]
lin_reg(x,y)
# Out:
# The r value is: 0.37964262096987134

# %% [markdown]
# Although the southern hemisphere looks less predicatable than the northern hemisphere, both models explain it is generally warmer the closer one gets to the equator. The southern hemisphere may look less predicatable because right now it is the "summer" season in the southern hemisphere and the "winter" season in northern hemisphere, therefore, the relationship might be stronger in June or July in the southern hemisphere, I would predict.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
fig_label = "north"
x = north["latitude"]
y = north["Humidity"]
lin_reg(x,y)
# Out:
# The r value is: 0.2592740947550629

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
fig_label = "south"
x = south["latitude"]
y = south["Humidity"]
lin_reg(x,y)
# Out:
# The r value is: 0.40380458701526994

# %% [markdown]
# No real relationship with humidity and proximity to the equator. in both northern and southern hemisphere you have positive sloping linear regression models with pretty week r squared values for each indicating not strong correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
fig_label = "north"
x = north["latitude"]
y = north["Cloudiness"]
lin_reg(x,y)
# Out:
# The r value is: 0.2418762340833948

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
fig_label="south"
x = south["latitude"]
y = south["Cloudiness"]
lin_reg(x,y)
# Out:
# The r value is: 0.13920193929194402

# %% [markdown]
# Similar analaysis here as the humidity and proximity to equator. very weak correlation between the variables, indicating it could be cloudy anywhere you go!

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
fig_label="north"
x = north["latitude"]
y = north["Wind Speed"]
lin_reg(x,y)
# Out:
# The r value is: 0.12546102864323289

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
fig_label="south"
x = south["latitude"]
y = south["Wind Speed"]
lin_reg(x,y)
# Out:
# The r value is: -0.27623056821566666

# %% [markdown]
# It appears there is a slight relationship trending toward lower wind speed as one gets closer to the equator, however the r value indicates not a strong correlation.
