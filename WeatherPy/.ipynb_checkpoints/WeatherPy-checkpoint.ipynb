# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
city_name = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

for city in cities:
    
    response = requests.get(query_url + city).json()
    
    try:
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Able to process {city}")

    except:
        print(f"not able to process {city}... skipping")
        pass
# Out:
# Able to process olafsvik
# Able to process kidal
# Able to process punta arenas
# Able to process hobart
# Able to process aguadilla
# Able to process marzuq
# Able to process chokurdakh
# Able to process abha
# not able to process kinanah... skipping
# Able to process upernavik
# Able to process mataura
# Able to process naze
# Able to process vaini
# Able to process nuuk
# Able to process akyab
# Able to process albany
# Able to process jamestown
# not able to process zlatoustovsk... skipping
# Able to process bengkulu
# Able to process cabedelo
# Able to process hilo
# Able to process rikitea
# not able to process barentsburg... skipping
# Able to process bay roberts
# Able to process shelburne
# Able to process thompson
# Able to process butaritari
# Able to process saint george
# Able to process puerto ayora
# Able to process srebrenik
# Able to process sibolga
# Able to process poum
# not able to process illoqqortoormiut... skipping
# Able to process busselton
# Able to process igrim
# Able to process taoudenni
# Able to process east london
# Able to process beringovskiy
# Able to process sao filipe
# Able to process atambua
# Able to process kahului
# not able to process nizhneyansk... skipping
# not able to process taolanaro... skipping
# Able to process buraydah
# Able to process lebu
# Able to process kilindoni
# Able to process samoded
# Able to process barrow
# not able to process phan rang... skipping
# Able to process vao
# Able to process deputatskiy
# Able to process lukovetskiy
# Able to process clyde river
# Able to process cape town
# Able to process port alfred
# Able to process tuktoyaktuk
# Able to process san borja
# Able to process kodiak
# Able to process lanzhou
# Able to process kushnarenkovo
# Able to process atuona
# not able to process amderma... skipping
# not able to process meyungs... skipping
# Able to process nikolskoye
# Able to process ozuluama
# Able to process norman wells
# not able to process louisbourg... skipping
# Able to process kavieng
# Able to process anito
# Able to process ushuaia
# Able to process kapaa
# Able to process la ronge
# Able to process laguna
# not able to process grand river south east... skipping
# Able to process hithadhoo
# Able to process hofn
# Able to process srednekolymsk
# Able to process kudahuvadhoo
# Able to process avarua
# Able to process lima
# Able to process chapais
# Able to process severo-kurilsk
# Able to process san andres
# Able to process verkhnevilyuysk
# Able to process dzaoudzi
# Able to process coari
# Able to process savannah bight
# Able to process codrington
# Able to process tura
# Able to process ilulissat
# Able to process bluff
# Able to process riyadh
# Able to process kaitangata
# Able to process kangaatsiaq
# Able to process saldanha
# Able to process khatanga
# Able to process hermanus
# Able to process adrar
# Able to process ubauro
# Able to process mar del plata
# Able to process prokudskoye
# not able to process labutta... skipping
# Able to process nouadhibou
# Able to process yanam
# Able to process katsuura
# Able to process yeppoon
# Able to process saint-philippe
# Able to process kruisfontein
# Able to process matara
# Able to process hazorasp
# Able to process bambous virieux
# Able to process ust-nera
# Able to process acapulco
# Able to process new norfolk
# Able to process aksarka
# Able to process castro
# not able to process palabuhanratu... skipping
# Able to process alofi
# Able to process necochea
# not able to process grand centre... skipping
# Able to process faanui
# Able to process bukama
# Able to process bredasdorp
# Able to process broken hill
# Able to process lavrentiya
# Able to process kilinochchi
# Able to process nalut
# Able to process champerico
# Able to process lagoa
# Able to process mount isa
# Able to process homer
# Able to process avera
# Able to process yellowknife
# Able to process darhan
# Able to process aklavik
# Able to process dudinka
# Able to process omboue
# Able to process arraial do cabo
# Able to process port-gentil
# Able to process chuy
# Able to process talcahuano
# Able to process ancud
# Able to process nandurbar
# Able to process dikson
# Able to process port lincoln
# Able to process nurota
# Able to process gravdal
# Able to process ternova
# Able to process cherskiy
# Able to process bethel
# Able to process doha
# Able to process isangel
# Able to process husavik
# Able to process popondetta
# Able to process neiafu
# Able to process mandalgovi
# Able to process georgetown
# Able to process eureka
# Able to process maningrida
# Able to process college
# Able to process port elizabeth
# Able to process lindi
# Able to process imeni poliny osipenko
# not able to process inderborskiy... skipping
# Able to process camana
# Able to process nanortalik
# Able to process nelson bay
# Able to process leningradskiy
# Able to process los llanos de aridane
# Able to process beaverlodge
# Able to process ribeira grande
# not able to process khonuu... skipping
# Able to process maarianhamina
# not able to process sentyabrskiy... skipping
# Able to process cayenne
# not able to process culipapa... skipping
# Able to process ocampo
# Able to process faya
# Able to process palmer
# Able to process tautira
# Able to process andra
# not able to process belushya guba... skipping
# Able to process vestmanna
# Able to process tarko-sale
# Able to process tasiilaq
# Able to process lompoc
# Able to process zyryanka
# Able to process atherton
# Able to process aasiaat
# not able to process tsihombe... skipping
# Able to process sur
# Able to process road town
# not able to process attawapiskat... skipping
# Able to process sitka
# Able to process flinders
# Able to process san policarpo
# Able to process bubaque
# Able to process at-bashi
# Able to process victoria
# Able to process broome
# Able to process taltal
# Able to process glendive
# Able to process khawhai
# Able to process bilma
# Able to process santa cruz
# Able to process itarema
# Able to process lata
# Able to process wattegama
# Able to process scottsbluff
# Able to process atar
# Able to process eldorado
# Able to process tual
# Able to process jinchang
# Able to process suoyarvi
# Able to process kurilsk
# not able to process artyk... skipping
# Able to process torbay
# Able to process jacksonville
# Able to process chokwe
# Able to process mahibadhoo
# Able to process san cristobal
# Able to process soyo
# Able to process havelock
# Able to process ngerengere
# Able to process qaanaaq
# Able to process inongo
# Able to process kawalu
# Able to process waipawa
# Able to process superior
# Able to process alamosa
# not able to process falealupo... skipping
# not able to process fevralsk... skipping
# Able to process asau
# Able to process san miguel
# Able to process voh
# Able to process meulaboh
# not able to process rungata... skipping
# Able to process manggar
# Able to process yerbogachen
# Able to process isla vista
# Able to process yulara
# Able to process geraldton
# Able to process san clemente
# not able to process umzimvubu... skipping
# Able to process nortelandia
# Able to process san patricio
# not able to process cockburn harbour... skipping
# Able to process shenjiamen
# Able to process sioni
# Able to process leua
# Able to process mantua
# Able to process manacapuru
# Able to process annau
# Able to process namatanai
# not able to process samusu... skipping
# Able to process tilichiki
# Able to process brae
# Able to process marabba
# Able to process bonavista
# Able to process ruvo di puglia
# Able to process aykhal
# Able to process cabo san lucas
# Able to process belmonte
# Able to process waitakere
# Able to process ossora
# Able to process pevek
# Able to process tuatapere
# Able to process cairns
# Able to process talnakh
# Able to process carnot
# Able to process tiksi
# Able to process proletariy
# Able to process airai
# Able to process sattenapalle
# Able to process vanavara
# Able to process boa vista
# Able to process fontanka
# Able to process dawson
# Able to process hambantota
# Able to process saskylakh
# not able to process tumannyy... skipping
# not able to process saleaula... skipping
# Able to process richards bay
# Able to process mehamn
# Able to process goure
# Able to process praia
# Able to process narsaq
# Able to process cam ranh
# Able to process ponta do sol
# Able to process altamont
# Able to process ukiah
# Able to process fortuna
# Able to process mahebourg
# Able to process provideniya
# Able to process biak
# Able to process yar-sale
# Able to process port blair
# Able to process makakilo city
# Able to process padang
# Able to process acarau
# Able to process nishihara
# Able to process lazaro cardenas
# Able to process weyburn
# Able to process kloulklubed
# Able to process mount gambier
# Able to process esperance
# Able to process qui nhon
# Able to process namibe
# Able to process anshun
# Able to process stokmarknes
# Able to process rio grande
# Able to process stettler
# Able to process bom jardim
# Able to process pitimbu
# Able to process iqaluit
# Able to process kem
# not able to process sinjah... skipping
# Able to process ranong
# Able to process caravelas
# Able to process kiama
# Able to process rocha
# Able to process constitucion
# Able to process grand-santi
# Able to process aksu
# Able to process mattru
# Able to process kieta
# Able to process samarai
# Able to process yatou
# Able to process sao joao da barra
# Able to process rocky mountain house
# Able to process juneau
# Able to process manado
# Able to process tadine
# Able to process luderitz
# Able to process pacific grove
# Able to process ternate
# Able to process waterboro
# Able to process smithers
# Able to process aras
# Able to process matagami
# Able to process lorengau
# Able to process ostrovnoy
# Able to process maputo
# Able to process amapa
# Able to process iquitos
# Able to process puerto escondido
# Able to process dongsheng
# Able to process svetlogorsk
# Able to process sterling
# Able to process vuktyl
# Able to process the valley
# Able to process kallaste
# not able to process vaitupu... skipping
# Able to process laurinburg
# Able to process vostok
# Able to process luanda
# Able to process eyl
# Able to process longyearbyen
# Able to process dingle
# Able to process fairbanks
# Able to process bandarbeyla
# not able to process sahrak... skipping
# Able to process sucre
# Able to process fare
# Able to process willowmore
# Able to process northam
# Able to process evensk
# Able to process ixtapa
# Able to process baruun-urt
# Able to process abu samrah
# Able to process grants
# Able to process belfast
# Able to process acajutla
# Able to process karasjok
# Able to process saurimo
# Able to process guerrero negro
# Able to process kifri
# Able to process cidreira
# Able to process kalmunai
# Able to process bowen
# Able to process kralendijk
# Able to process luxor
# Able to process shu
# Able to process tocopilla
# Able to process bonthe
# Able to process beyneu
# Able to process kiboga
# Able to process port hawkesbury
# Able to process fiche
# not able to process marcona... skipping
# Able to process sinnamary
# Able to process sabang
# Able to process hvide sande
# Able to process khash
# Able to process ocean city
# Able to process oktyabrskiy
# Able to process mae hong son
# Able to process tornio
# not able to process panjwin... skipping
# not able to process unye... skipping
# Able to process lichinga
# Able to process rio cuarto
# Able to process gamba
# Able to process icod de los vinos
# Able to process benguela
# Able to process puerto montt
# Able to process elizabeth city
# not able to process skalistyy... skipping
# Able to process canutama
# Able to process cururupu
# Able to process mayumba
# Able to process araxa
# Able to process innisfail
# Able to process leh
# Able to process porto novo
# Able to process piranhas
# Able to process ballina
# Able to process salalah
# Able to process boffa
# Able to process wichian buri
# Able to process valparaiso
# Able to process kouroussa
# Able to process siverek
# Able to process jiazi
# Able to process talant
# Able to process andros town
# Able to process ornskoldsvik
# Able to process vila velha
# Able to process barabai
# Able to process belaya gora
# Able to process lodwar
# Able to process pout
# Able to process cape canaveral
# Able to process guadalajara
# Able to process oistins
# Able to process vieux-habitants
# Able to process oktyabrskoye
# Able to process berdigestyakh
# Able to process sorland
# Able to process pafos
# Able to process dubti
# Able to process miri
# Able to process souillac
# not able to process higuey... skipping
# Able to process iskateley
# Able to process sept-iles
# Able to process aquiraz
# Able to process praya
# Able to process carnarvon
# Able to process adre
# Able to process mucuri
# Able to process saint-joseph
# Able to process gurupa
# Able to process pangnirtung
# Able to process havoysund
# Able to process mirabad
# Able to process tuyen quang
# Able to process wlodawa
# Able to process mayenne
# Able to process pilar
# not able to process otradinskiy... skipping
# not able to process tabiauea... skipping
# not able to process kazalinsk... skipping
# Able to process high level
# Able to process kuandian
# Able to process zarand
# Able to process san fernando
# Able to process hamilton
# Able to process floro
# Able to process young
# Able to process denpasar
# Able to process dubbo
# Able to process palu
# Able to process banda aceh
# not able to process bursol... skipping
# Able to process seminole
# Able to process jijiga
# Able to process yumen
# Able to process hasaki
# Able to process lingao
# Able to process rapid valley
# Able to process ust-tsilma
# Able to process nanning
# Able to process bairiki
# Able to process vardo
# Able to process high rock
# Able to process pankovka
# Able to process potsdam
# Able to process conway
# Able to process tambopata
# Able to process harlow
# Able to process byron bay
# Able to process plettenberg bay
# Able to process babushkin
# not able to process armacao dos buzios... skipping
# Able to process ceres
# Able to process mgandu
# Able to process kisanga
# Able to process lithakia
# Able to process zlitan
# Able to process makasar
# Able to process klaksvik
# Able to process makinsk
# Able to process hami
# Able to process manaus
# Able to process ulladulla
# Able to process kingston
# Able to process solnechnyy
# Able to process nome
# Able to process marsh harbour
# Able to process phitsanulok
# Able to process ahipara
# Able to process quatre cocos
# Able to process murmansk
# Able to process nardaran
# Able to process pula
# not able to process sento se... skipping
# Able to process maragogi
# Able to process jambi
# Able to process tucuman
# Able to process mitsamiouli
# Able to process touros
# Able to process bull savanna
# Able to process progreso
# Able to process jiayuguan
# Able to process tommot
# Able to process ferme-neuve
# Able to process santa ana
# Able to process roma
# Able to process kotma
# Able to process mokhotlong
# Able to process moose jaw
# Able to process skara
# Able to process sakaiminato
# Able to process dauphin
# Able to process japura
# Able to process ribeira brava
# Able to process antofagasta
# Able to process hobyo
# Able to process aurora
# Able to process tawang
# Able to process shatrovo
# Able to process la rioja
# Able to process kichera
# Able to process moindou
# Able to process monrovia
# Able to process little current
# Able to process alta floresta
# Able to process illapel
# Able to process shingu
# Able to process sri aman
# Able to process orotukan
# Able to process vershino-shakhtaminskiy
# Able to process mbaiki
# Able to process chumikan
# Able to process san ramon
# Able to process sindor
# Able to process karratha
# Able to process gizo
# Able to process nova granada
# Able to process berlevag
# Able to process bathsheba
# Able to process ranfurly
# Able to process pisco
# Able to process thyboron
# Able to process erenhot
# Able to process kozhva
# Able to process burns lake
# Able to process ostersund
# Able to process songea
# Able to process russell
# Able to process flin flon
# Able to process gazli
# Able to process tomatlan
# Able to process ayan
# Able to process wewak
# Able to process gat
# Able to process vanimo
# Able to process lillehammer
# Able to process nagahama
# Able to process andenes
# Able to process gejiu
# Able to process tsukumi
# Able to process catamarca
# Able to process mamlyutka
# Able to process te anau
# Able to process snasa
# Able to process arica
# Able to process tailai
# Able to process norilsk
# Able to process jonuta
# Able to process sehithwa
# Able to process manati
# Able to process carmen
# Able to process nadapuram
# not able to process mys shmidta... skipping
# Able to process sonoita
# Able to process oranjestad
# Able to process grandview
# Able to process cherdyn
# Able to process tiznit
# Able to process tairua

# %%
dataframe_results = pd.DataFrame({"City Name":city_name,
                                 "Cloudiness":cloudiness,
                                 "Country": country,
                                 "Date": date,
                                 "Humidity": humidity,
                                 "latitude": latitude,
                                 "longitude": longitude,
                                 "Max Temp (fahrenheit)": max_temp,
                                 "Wind Speed": wind_speed})

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
dataframe_results.to_csv(output_data_file)

# %%
dataframe_results.head()
# Out:
#       City Name  Cloudiness Country        Date  Humidity  latitude  \
# 0      Olafsvik          44      IS  1579319718        64     64.89
# 1         Kidal         100      ML  1579319718        33     18.44
# 2  Punta Arenas          40      CL  1579319718        76    -53.15
# 3        Hobart          20      AU  1579319718        37    -42.88
# 4     Aguadilla          40      PR  1579319649        87     18.43
#
#    longitude  Max Temp (fahrenheit)  Wind Speed
# 0     -23.71                  33.73       17.02
# 1       1.41                  60.55       13.51
# 2     -70.92                  50.00       19.46
# 3     147.33                  66.20       12.75
# 4     -67.15                  75.99        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Max Temp (fahrenheit)"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Max Temp")
plt.ylabel("Max Temp (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Max_Temp")
plt.show()

# %% [markdown]
# Above appears to show temperatures are higher around the equator (0 latitude) and temperatures trend lower as you go further away from the equator, both north and south.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Humidity"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Humidity")
plt.show()

# %% [markdown]
# Doesn't appear to be much pattern to humidity levels. You might say there are more lower humidity levels at the latitudes closer to the equator, but hard to tell from this scatter, because there are also a lot of very high humidity cities near and far from equator.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Cloudiness"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Cloudiness")
plt.show()

# %% [markdown]
# This isn't telling a whole lot either. It looks like there are particular numbers that are more frequently chosen to represent "cloudiness" in any given city. Would not be able to infer from this scatter that it is more or less cloudy near the equator.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_plots = dataframe_results["latitude"]
y_plots = dataframe_results["Wind Speed"]
plt.scatter(x_plots, y_plots, color = "darkblue")
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("output_data/Latitude vs Wind Speed")
plt.show()

# %% [markdown]
# Wind speeds this particular day were pretty consistent no matter what city. 0-20 would pretty much describe the wind speed both near or far from the equator - a couple outliers up well north of the equator with very high winds.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
fig_label=[]
def lin_reg(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values, "r-")
    plt.xlabel(x.name)
    plt.ylabel(y.name)
    plt.title(f'{x.name} vs {y.name}')
    plt.annotate(line_eq,(min(x),min(y)),fontsize=15, color="red")
    plt.savefig(f"output_data/{x.name}vs{y.name}:{fig_label}")
    plt.show()
    print(f'The r-squared value is: {rvalue}')

# %%
# Create Northern and Southern Hemisphere DataFrames
north = dataframe_results.loc[dataframe_results["latitude"]>=0]
south = dataframe_results.loc[dataframe_results["latitude"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
fig_label = "north"
x = north["latitude"]
y = north["Max Temp (fahrenheit)"]
lin_reg(x,y)
# Out:
# The r-squared value is: -0.8688343264253795

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
fig_label = "south"
x = south["latitude"]
y = south["Max Temp (fahrenheit)"]
lin_reg(x,y)
# Out:
# The r-squared value is: 0.5253167992891618

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
fig_label = "north"
x = north["latitude"]
y = north["Humidity"]
lin_reg(x,y)
# Out:
# The r-squared value is: 0.3479683273299269

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
fig_label = "south"
x = south["latitude"]
y = south["Humidity"]
lin_reg(x,y)
# Out:
# The r-squared value is: 0.3342235187101515

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
fig_label = "north"
x = north["latitude"]
y = north["Cloudiness"]
lin_reg(x,y)
# Out:
# The r-squared value is: 0.2728097737436911

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
fig_label="south"
x = south["latitude"]
y = south["Cloudiness"]
lin_reg(x,y)
# Out:
# The r-squared value is: 0.11801365556720456

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
fig_label="north"
x = north["latitude"]
y = north["Wind Speed"]
lin_reg(x,y)
# Out:
# The r-squared value is: 0.019802154016729495

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
fig_label="south"
x = south["latitude"]
y = south["Wind Speed"]
lin_reg(x,y)
# Out:
# The r-squared value is: -0.15203553078921472
